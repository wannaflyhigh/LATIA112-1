# %% [markdown]
# 抓取教育領域的所有學生數

# %%
from math import floor
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import chromedriver_autoinstaller_fix
from time import sleep

# 安裝chrome webdriver
chromedriver_autoinstaller_fix.install()

# 讓webdriver開啟我們要的網站
driver = webdriver.Chrome()
driver.get("https://stats.moe.gov.tw/bcode/")

# 選擇搜尋條件並按下查詢
driver.find_element(By.ID, "RadioButtonList2_2").click()
SelectElem = driver.find_element(By.NAME, "DropDownList1")
Select(SelectElem).select_by_value("01")
driver.find_element(By.ID, "Button1").click()

# 先建立一個陣列來放要存進csv的資料
table = [["學年度", "學校", "體系別", "設立別", "學校", "代碼", "學校名稱", "領域代碼/名稱", "學門代碼/名稱",
          "學類代碼/名稱", "系學類代碼/名稱", "科系代碼", "科系名稱", "日間/進修別", "等級別", "學生數總計", "男學生數", "女學生數"]]

totalPage = floor(int(driver.find_element(
    By.ID, 'RecordCnt').find_element(By.TAG_NAME, "font").text)/10+1)

print("totalPage", totalPage)

for currentpage in range(1, totalPage):
    for i, row in enumerate(driver.find_elements(By.CLASS_NAME, "GridViewRowStyle")):
        rowData = []
        for column in row.find_elements(By.TAG_NAME, "td"):
            rowData.append(column.text)
        table.append(rowData)

    nextPage = driver.find_element(By.ID, 'BtnNext')
    nextPage.click()
    print("currentpage", currentpage)
    # 避免伺服器壓力過大
    sleep(1)


sleep(5)
driver.close()

table

# 小失誤 range(1,1157)不會有1157
# Out:
# totalPage 1157
# currentpage 1
# currentpage 2
# currentpage 3
# currentpage 4
# currentpage 5
# currentpage 6
# currentpage 7
# currentpage 8
# currentpage 9
# currentpage 10
# currentpage 11
# currentpage 12
# currentpage 13
# currentpage 14
# currentpage 15
# currentpage 16
# currentpage 17
# currentpage 18
# currentpage 19
# currentpage 20
# currentpage 21
# currentpage 22
# currentpage 23
# currentpage 24
# currentpage 25
# currentpage 26
# currentpage 27
# currentpage 28
# currentpage 29
# currentpage 30
# currentpage 31
# currentpage 32
# currentpage 33
# currentpage 34
# currentpage 35
# currentpage 36
# currentpage 37
# currentpage 38
# currentpage 39
# currentpage 40
# currentpage 41
# currentpage 42
# currentpage 43
# currentpage 44
# currentpage 45
# currentpage 46
# currentpage 47
# currentpage 48
# currentpage 49
# currentpage 50
# currentpage 51
# currentpage 52
# currentpage 53
# currentpage 54
# currentpage 55
# currentpage 56
# currentpage 57
# currentpage 58
# currentpage 59
# currentpage 60
# currentpage 61
# currentpage 62
# currentpage 63
# currentpage 64
# currentpage 65
# currentpage 66
# currentpage 67
# currentpage 68
# currentpage 69
# currentpage 70
# currentpage 71
# currentpage 72
# currentpage 73
# currentpage 74
# currentpage 75
# currentpage 76
# currentpage 77
# currentpage 78
# currentpage 79
# currentpage 80
# currentpage 81
# currentpage 82
# currentpage 83
# currentpage 84
# currentpage 85
# currentpage 86
# currentpage 87
# currentpage 88
# currentpage 89
# currentpage 90
# currentpage 91
# currentpage 92
# currentpage 93
# currentpage 94
# currentpage 95
# currentpage 96
# currentpage 97
# currentpage 98
# currentpage 99
# currentpage 100
# currentpage 101
# currentpage 102
# currentpage 103
# currentpage 104
# currentpage 105
# currentpage 106
# currentpage 107
# currentpage 108
# currentpage 109
# currentpage 110
# currentpage 111
# currentpage 112
# currentpage 113
# currentpage 114
# currentpage 115
# currentpage 116
# currentpage 117
# currentpage 118
# currentpage 119
# currentpage 120
# currentpage 121
# currentpage 122
# currentpage 123
# currentpage 124
# currentpage 125
# currentpage 126
# currentpage 127
# currentpage 128
# currentpage 129
# currentpage 130
# currentpage 131
# currentpage 132
# currentpage 133
# currentpage 134
# currentpage 135
# currentpage 136
# currentpage 137
# currentpage 138
# currentpage 139
# currentpage 140
# currentpage 141
# currentpage 142
# currentpage 143
# currentpage 144
# currentpage 145
# currentpage 146
# currentpage 147
# currentpage 148
# currentpage 149
# currentpage 150
# currentpage 151
# currentpage 152
# currentpage 153
# currentpage 154
# currentpage 155
# currentpage 156
# currentpage 157
# currentpage 158
# currentpage 159
# currentpage 160
# currentpage 161
# currentpage 162
# currentpage 163
# currentpage 164
# currentpage 165
# currentpage 166
# currentpage 167
# currentpage 168
# currentpage 169
# currentpage 170
# currentpage 171
# currentpage 172
# currentpage 173
# currentpage 174
# currentpage 175
# currentpage 176
# currentpage 177
# currentpage 178
# currentpage 179
# currentpage 180
# currentpage 181
# currentpage 182
# currentpage 183
# currentpage 184
# currentpage 185
# currentpage 186
# currentpage 187
# currentpage 188
# currentpage 189
# currentpage 190
# currentpage 191
# currentpage 192
# currentpage 193
# currentpage 194
# currentpage 195
# currentpage 196
# currentpage 197
# currentpage 198
# currentpage 199
# currentpage 200
# currentpage 201
# currentpage 202
# currentpage 203
# currentpage 204
# currentpage 205
# currentpage 206
# currentpage 207
# currentpage 208
# currentpage 209
# currentpage 210
# currentpage 211
# currentpage 212
# currentpage 213
# currentpage 214
# currentpage 215
# currentpage 216
# currentpage 217
# currentpage 218
# currentpage 219
# currentpage 220
# currentpage 221
# currentpage 222
# currentpage 223
# currentpage 224
# currentpage 225
# currentpage 226
# currentpage 227
# currentpage 228
# currentpage 229
# currentpage 230
# currentpage 231
# currentpage 232
# currentpage 233
# currentpage 234
# currentpage 235
# currentpage 236
# currentpage 237
# currentpage 238
# currentpage 239
# currentpage 240
# currentpage 241
# currentpage 242
# currentpage 243
# currentpage 244
# currentpage 245
# currentpage 246
# currentpage 247
# currentpage 248
# currentpage 249
# currentpage 250
# currentpage 251
# currentpage 252
# currentpage 253
# currentpage 254
# currentpage 255
# currentpage 256
# currentpage 257
# currentpage 258
# currentpage 259
# currentpage 260
# currentpage 261
# currentpage 262
# currentpage 263
# currentpage 264
# currentpage 265
# currentpage 266
# currentpage 267
# currentpage 268
# currentpage 269
# currentpage 270
# currentpage 271
# currentpage 272
# currentpage 273
# currentpage 274
# currentpage 275
# currentpage 276
# currentpage 277
# currentpage 278
# currentpage 279
# currentpage 280
# currentpage 281
# currentpage 282
# currentpage 283
# currentpage 284
# currentpage 285
# currentpage 286
# currentpage 287
# currentpage 288
# currentpage 289
# currentpage 290
# currentpage 291
# currentpage 292
# currentpage 293
# currentpage 294
# currentpage 295
# currentpage 296
# currentpage 297
# currentpage 298
# currentpage 299
# currentpage 300
# currentpage 301
# currentpage 302
# currentpage 303
# currentpage 304
# currentpage 305
# currentpage 306
# currentpage 307
# currentpage 308
# currentpage 309
# currentpage 310
# currentpage 311
# currentpage 312
# currentpage 313
# currentpage 314
# currentpage 315
# currentpage 316
# currentpage 317
# currentpage 318
# currentpage 319
# currentpage 320
# currentpage 321
# currentpage 322
# currentpage 323
# currentpage 324
# currentpage 325
# currentpage 326
# currentpage 327
# currentpage 328
# currentpage 329
# currentpage 330
# currentpage 331
# currentpage 332
# currentpage 333
# currentpage 334
# currentpage 335
# currentpage 336
# currentpage 337
# currentpage 338
# currentpage 339
# currentpage 340
# currentpage 341
# currentpage 342
# currentpage 343
# currentpage 344
# currentpage 345
# currentpage 346
# currentpage 347
# currentpage 348
# currentpage 349
# currentpage 350
# currentpage 351
# currentpage 352
# currentpage 353
# currentpage 354
# currentpage 355
# currentpage 356
# currentpage 357
# currentpage 358
# currentpage 359
# currentpage 360
# currentpage 361
# currentpage 362
# currentpage 363
# currentpage 364
# currentpage 365
# currentpage 366
# currentpage 367
# currentpage 368
# currentpage 369
# currentpage 370
# currentpage 371
# currentpage 372
# currentpage 373
# currentpage 374
# currentpage 375
# currentpage 376
# currentpage 377
# currentpage 378
# currentpage 379
# currentpage 380
# currentpage 381
# currentpage 382
# currentpage 383
# currentpage 384
# currentpage 385
# currentpage 386
# currentpage 387
# currentpage 388
# currentpage 389
# currentpage 390
# currentpage 391
# currentpage 392
# currentpage 393
# currentpage 394
# currentpage 395
# currentpage 396
# currentpage 397
# currentpage 398
# currentpage 399
# currentpage 400
# currentpage 401
# currentpage 402
# currentpage 403
# currentpage 404
# currentpage 405
# currentpage 406
# currentpage 407
# currentpage 408
# currentpage 409
# currentpage 410
# currentpage 411
# currentpage 412
# currentpage 413
# currentpage 414
# currentpage 415
# currentpage 416
# currentpage 417
# currentpage 418
# currentpage 419
# currentpage 420
# currentpage 421
# currentpage 422
# currentpage 423
# currentpage 424
# currentpage 425
# currentpage 426
# currentpage 427
# currentpage 428
# currentpage 429
# currentpage 430
# currentpage 431
# currentpage 432
# currentpage 433
# currentpage 434
# currentpage 435
# currentpage 436
# currentpage 437
# currentpage 438
# currentpage 439
# currentpage 440
# currentpage 441
# currentpage 442
# currentpage 443
# currentpage 444
# currentpage 445
# currentpage 446
# currentpage 447
# currentpage 448
# currentpage 449
# currentpage 450
# currentpage 451
# currentpage 452
# currentpage 453
# currentpage 454
# currentpage 455
# currentpage 456
# currentpage 457
# currentpage 458
# currentpage 459
# currentpage 460
# currentpage 461
# currentpage 462
# currentpage 463
# currentpage 464
# currentpage 465
# currentpage 466
# currentpage 467
# currentpage 468
# currentpage 469
# currentpage 470
# currentpage 471
# currentpage 472
# currentpage 473
# currentpage 474
# currentpage 475
# currentpage 476
# currentpage 477
# currentpage 478
# currentpage 479
# currentpage 480
# currentpage 481
# currentpage 482
# currentpage 483
# currentpage 484
# currentpage 485
# currentpage 486
# currentpage 487
# currentpage 488
# currentpage 489
# currentpage 490
# currentpage 491
# currentpage 492
# currentpage 493
# currentpage 494
# currentpage 495
# currentpage 496
# currentpage 497
# currentpage 498
# currentpage 499
# currentpage 500
# currentpage 501
# currentpage 502
# currentpage 503
# currentpage 504
# currentpage 505
# currentpage 506
# currentpage 507
# currentpage 508
# currentpage 509
# currentpage 510
# currentpage 511
# currentpage 512
# currentpage 513
# currentpage 514
# currentpage 515
# currentpage 516
# currentpage 517
# currentpage 518
# currentpage 519
# currentpage 520
# currentpage 521
# currentpage 522
# currentpage 523
# currentpage 524
# currentpage 525
# currentpage 526
# currentpage 527
# currentpage 528
# currentpage 529
# currentpage 530
# currentpage 531
# currentpage 532
# currentpage 533
# currentpage 534
# currentpage 535
# currentpage 536
# currentpage 537
# currentpage 538
# currentpage 539
# currentpage 540
# currentpage 541
# currentpage 542
# currentpage 543
# currentpage 544
# currentpage 545
# currentpage 546
# currentpage 547
# currentpage 548
# currentpage 549
# currentpage 550
# currentpage 551
# currentpage 552
# currentpage 553
# currentpage 554
# currentpage 555
# currentpage 556
# currentpage 557
# currentpage 558
# currentpage 559
# currentpage 560
# currentpage 561
# currentpage 562
# currentpage 563
# currentpage 564
# currentpage 565
# currentpage 566
# currentpage 567
# currentpage 568
# currentpage 569
# currentpage 570
# currentpage 571
# currentpage 572
# currentpage 573
# currentpage 574
# currentpage 575
# currentpage 576
# currentpage 577
# currentpage 578
# currentpage 579
# currentpage 580
# currentpage 581
# currentpage 582
# currentpage 583
# currentpage 584
# currentpage 585
# currentpage 586
# currentpage 587
# currentpage 588
# currentpage 589
# currentpage 590
# currentpage 591
# currentpage 592
# currentpage 593
# currentpage 594
# currentpage 595
# currentpage 596
# currentpage 597
# currentpage 598
# currentpage 599
# currentpage 600
# currentpage 601
# currentpage 602
# currentpage 603
# currentpage 604
# currentpage 605
# currentpage 606
# currentpage 607
# currentpage 608
# currentpage 609
# currentpage 610
# currentpage 611
# currentpage 612
# currentpage 613
# currentpage 614
# currentpage 615
# currentpage 616
# currentpage 617
# currentpage 618
# currentpage 619
# currentpage 620
# currentpage 621
# currentpage 622
# currentpage 623
# currentpage 624
# currentpage 625
# currentpage 626
# currentpage 627
# currentpage 628
# currentpage 629
# currentpage 630
# currentpage 631
# currentpage 632
# currentpage 633
# currentpage 634
# currentpage 635
# currentpage 636
# currentpage 637
# currentpage 638
# currentpage 639
# currentpage 640
# currentpage 641
# currentpage 642
# currentpage 643
# currentpage 644
# currentpage 645
# currentpage 646
# currentpage 647
# currentpage 648
# currentpage 649
# currentpage 650
# currentpage 651
# currentpage 652
# currentpage 653
# currentpage 654
# currentpage 655
# currentpage 656
# currentpage 657
# currentpage 658
# currentpage 659
# currentpage 660
# currentpage 661
# currentpage 662
# currentpage 663
# currentpage 664
# currentpage 665
# currentpage 666
# currentpage 667
# currentpage 668
# currentpage 669
# currentpage 670
# currentpage 671
# currentpage 672
# currentpage 673
# currentpage 674
# currentpage 675
# currentpage 676
# currentpage 677
# currentpage 678
# currentpage 679
# currentpage 680
# currentpage 681
# currentpage 682
# currentpage 683
# currentpage 684
# currentpage 685
# currentpage 686
# currentpage 687
# currentpage 688
# currentpage 689
# currentpage 690
# currentpage 691
# currentpage 692
# currentpage 693
# currentpage 694
# currentpage 695
# currentpage 696
# currentpage 697
# currentpage 698
# currentpage 699
# currentpage 700
# currentpage 701
# currentpage 702
# currentpage 703
# currentpage 704
# currentpage 705
# currentpage 706
# currentpage 707
# currentpage 708
# currentpage 709
# currentpage 710
# currentpage 711
# currentpage 712
# currentpage 713
# currentpage 714
# currentpage 715
# currentpage 716
# currentpage 717
# currentpage 718
# currentpage 719
# currentpage 720
# currentpage 721
# currentpage 722
# currentpage 723
# currentpage 724
# currentpage 725
# currentpage 726
# currentpage 727
# currentpage 728
# currentpage 729
# currentpage 730
# currentpage 731
# currentpage 732
# currentpage 733
# currentpage 734
# currentpage 735
# currentpage 736
# currentpage 737
# currentpage 738
# currentpage 739
# currentpage 740
# currentpage 741
# currentpage 742
# currentpage 743
# currentpage 744
# currentpage 745
# currentpage 746
# currentpage 747
# currentpage 748
# currentpage 749
# currentpage 750
# currentpage 751
# currentpage 752
# currentpage 753
# currentpage 754
# currentpage 755
# currentpage 756
# currentpage 757
# currentpage 758
# currentpage 759
# currentpage 760
# currentpage 761
# currentpage 762
# currentpage 763
# currentpage 764
# currentpage 765
# currentpage 766
# currentpage 767
# currentpage 768
# currentpage 769
# currentpage 770
# currentpage 771
# currentpage 772
# currentpage 773
# currentpage 774
# currentpage 775
# currentpage 776
# currentpage 777
# currentpage 778
# currentpage 779
# currentpage 780
# currentpage 781
# currentpage 782
# currentpage 783
# currentpage 784
# currentpage 785
# currentpage 786
# currentpage 787
# currentpage 788
# currentpage 789
# currentpage 790
# currentpage 791
# currentpage 792
# currentpage 793
# currentpage 794
# currentpage 795
# currentpage 796
# currentpage 797
# currentpage 798
# currentpage 799
# currentpage 800
# currentpage 801
# currentpage 802
# currentpage 803
# currentpage 804
# currentpage 805
# currentpage 806
# currentpage 807
# currentpage 808
# currentpage 809
# currentpage 810
# currentpage 811
# currentpage 812
# currentpage 813
# currentpage 814
# currentpage 815
# currentpage 816
# currentpage 817
# currentpage 818
# currentpage 819
# currentpage 820
# currentpage 821
# currentpage 822
# currentpage 823
# currentpage 824
# currentpage 825
# currentpage 826
# currentpage 827
# currentpage 828
# currentpage 829
# currentpage 830
# currentpage 831
# currentpage 832
# currentpage 833
# currentpage 834
# currentpage 835
# currentpage 836
# currentpage 837
# currentpage 838
# currentpage 839
# currentpage 840
# currentpage 841
# currentpage 842
# currentpage 843
# currentpage 844
# currentpage 845
# currentpage 846
# currentpage 847
# currentpage 848
# currentpage 849
# currentpage 850
# currentpage 851
# currentpage 852
# currentpage 853
# currentpage 854
# currentpage 855
# currentpage 856
# currentpage 857
# currentpage 858
# currentpage 859
# currentpage 860
# currentpage 861
# currentpage 862
# currentpage 863
# currentpage 864
# currentpage 865
# currentpage 866
# currentpage 867
# currentpage 868
# currentpage 869
# currentpage 870
# currentpage 871
# currentpage 872
# currentpage 873
# currentpage 874
# currentpage 875
# currentpage 876
# currentpage 877
# currentpage 878
# currentpage 879
# currentpage 880
# currentpage 881
# currentpage 882
# currentpage 883
# currentpage 884
# currentpage 885
# currentpage 886
# currentpage 887
# currentpage 888
# currentpage 889
# currentpage 890
# currentpage 891
# currentpage 892
# currentpage 893
# currentpage 894
# currentpage 895
# currentpage 896
# currentpage 897
# currentpage 898
# currentpage 899
# currentpage 900
# currentpage 901
# currentpage 902
# currentpage 903
# currentpage 904
# currentpage 905
# currentpage 906
# currentpage 907
# currentpage 908
# currentpage 909
# currentpage 910
# currentpage 911
# currentpage 912
# currentpage 913
# currentpage 914
# currentpage 915
# currentpage 916
# currentpage 917
# currentpage 918
# currentpage 919
# currentpage 920
# currentpage 921
# currentpage 922
# currentpage 923
# currentpage 924
# currentpage 925
# currentpage 926
# currentpage 927
# currentpage 928
# currentpage 929
# currentpage 930
# currentpage 931
# currentpage 932
# currentpage 933
# currentpage 934
# currentpage 935
# currentpage 936
# currentpage 937
# currentpage 938
# currentpage 939
# currentpage 940
# currentpage 941
# currentpage 942
# currentpage 943
# currentpage 944
# currentpage 945
# currentpage 946
# currentpage 947
# currentpage 948
# currentpage 949
# currentpage 950
# currentpage 951
# currentpage 952
# currentpage 953
# currentpage 954
# currentpage 955
# currentpage 956
# currentpage 957
# currentpage 958
# currentpage 959
# currentpage 960
# currentpage 961
# currentpage 962
# currentpage 963
# currentpage 964
# currentpage 965
# currentpage 966
# currentpage 967
# currentpage 968
# currentpage 969
# currentpage 970
# currentpage 971
# currentpage 972
# currentpage 973
# currentpage 974
# currentpage 975
# currentpage 976
# currentpage 977
# currentpage 978
# currentpage 979
# currentpage 980
# currentpage 981
# currentpage 982
# currentpage 983
# currentpage 984
# currentpage 985
# currentpage 986
# currentpage 987
# currentpage 988
# currentpage 989
# currentpage 990
# currentpage 991
# currentpage 992
# currentpage 993
# currentpage 994
# currentpage 995
# currentpage 996
# currentpage 997
# currentpage 998
# currentpage 999
# currentpage 1000
# currentpage 1001
# currentpage 1002
# currentpage 1003
# currentpage 1004
# currentpage 1005
# currentpage 1006
# currentpage 1007
# currentpage 1008
# currentpage 1009
# currentpage 1010
# currentpage 1011
# currentpage 1012
# currentpage 1013
# currentpage 1014
# currentpage 1015
# currentpage 1016
# currentpage 1017
# currentpage 1018
# currentpage 1019
# currentpage 1020
# currentpage 1021
# currentpage 1022
# currentpage 1023
# currentpage 1024
# currentpage 1025
# currentpage 1026
# currentpage 1027
# currentpage 1028
# currentpage 1029
# currentpage 1030
# currentpage 1031
# currentpage 1032
# currentpage 1033
# currentpage 1034
# currentpage 1035
# currentpage 1036
# currentpage 1037
# currentpage 1038
# currentpage 1039
# currentpage 1040
# currentpage 1041
# currentpage 1042
# currentpage 1043
# currentpage 1044
# currentpage 1045
# currentpage 1046
# currentpage 1047
# currentpage 1048
# currentpage 1049
# currentpage 1050
# currentpage 1051
# currentpage 1052
# currentpage 1053
# currentpage 1054
# currentpage 1055
# currentpage 1056
# currentpage 1057
# currentpage 1058
# currentpage 1059
# currentpage 1060
# currentpage 1061
# currentpage 1062
# currentpage 1063
# currentpage 1064
# currentpage 1065
# currentpage 1066
# currentpage 1067
# currentpage 1068
# currentpage 1069
# currentpage 1070
# currentpage 1071
# currentpage 1072
# currentpage 1073
# currentpage 1074
# currentpage 1075
# currentpage 1076
# currentpage 1077
# currentpage 1078
# currentpage 1079
# currentpage 1080
# currentpage 1081
# currentpage 1082
# currentpage 1083
# currentpage 1084
# currentpage 1085
# currentpage 1086
# currentpage 1087
# currentpage 1088
# currentpage 1089
# currentpage 1090
# currentpage 1091
# currentpage 1092
# currentpage 1093
# currentpage 1094
# currentpage 1095
# currentpage 1096
# currentpage 1097
# currentpage 1098
# currentpage 1099
# currentpage 1100
# currentpage 1101
# currentpage 1102
# currentpage 1103
# currentpage 1104
# currentpage 1105
# currentpage 1106
# currentpage 1107
# currentpage 1108
# currentpage 1109
# currentpage 1110
# currentpage 1111
# currentpage 1112
# currentpage 1113
# currentpage 1114
# currentpage 1115
# currentpage 1116
# currentpage 1117
# currentpage 1118
# currentpage 1119
# currentpage 1120
# currentpage 1121
# currentpage 1122
# currentpage 1123
# currentpage 1124
# currentpage 1125
# currentpage 1126
# currentpage 1127
# currentpage 1128
# currentpage 1129
# currentpage 1130
# currentpage 1131
# currentpage 1132
# currentpage 1133
# currentpage 1134
# currentpage 1135
# currentpage 1136
# currentpage 1137
# currentpage 1138
# currentpage 1139
# currentpage 1140
# currentpage 1141
# currentpage 1142
# currentpage 1143
# currentpage 1144
# currentpage 1145
# currentpage 1146
# currentpage 1147
# currentpage 1148
# currentpage 1149
# currentpage 1150
# currentpage 1151
# currentpage 1152
# currentpage 1153
# currentpage 1154
# currentpage 1155
# currentpage 1156
# [['學年度',
#   '學校',
#   '體系別',
#   '設立別',
#   '學校',
#   '代碼',
#   '學校名稱',
#   '領域代碼/名稱',
#   '學門代碼/名稱',
#   '學類代碼/名稱',
#   '系學類代碼/名稱',
#   '科系代碼',
#   '科系名稱',
#   '日間/進修別',
#   '等級別',
#   '學生數總計',
#   '男學生數',
#   '女學生數'],
#  ['111',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'D 博士',
#   '101',
#   '45',
#   '56'],
#  ['111',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'M 碩士',
#   '39',
#   '15',
#   '24'],
#  ['111',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'B 學士',
#   '218',
#   '78',
#   '140'],
#  ['111',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114005',
#   '教育行政與政策研究所',
#   'D 日',
#   'M 碩士',
#   '48',
#   '14',
#   '34'],
#  ['111',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114006',
#   '學校行政碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '80',
#   '28',
#   '52'],
#  ['111',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121004',
#   '幼兒教育研究所',
#   'D 日',
#   'M 碩士',
#   '54',
#   '5',
#   '49'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系',
#   'D 日',
#   'D 博士',
#   '63',
#   '21',
#   '42'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系',
#   'D 日',
#   'M 碩士',
#   '116',
#   '19',
#   '97'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系',
#   'D 日',
#   'B 學士',
#   '184',
#   '51',
#   '133'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系教育行政碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '59',
#   '11',
#   '48'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系課程與教學碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '135',
#   '18',
#   '117'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111112',
#   '竹師教育學院學士班',
#   'D 日',
#   'B 學士',
#   '135',
#   '58',
#   '77'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113095',
#   '特殊教育學系',
#   'D 日',
#   'M 碩士',
#   '59',
#   '4',
#   '55'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113095',
#   '特殊教育學系',
#   'D 日',
#   'B 學士',
#   '158',
#   '27',
#   '131'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113110',
#   '學前特殊教育碩士在職學位學程',
#   'N 職',
#   'M 碩士',
#   '10',
#   '-',
#   '10'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115124',
#   '華德福教育碩士在職學位學程',
#   'N 職',
#   'M 碩士',
#   '24',
#   '4',
#   '20'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121091',
#   '幼兒教育學系',
#   'D 日',
#   'M 碩士',
#   '68',
#   '7',
#   '61'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121091',
#   '幼兒教育學系',
#   'D 日',
#   'B 學士',
#   '162',
#   '10',
#   '152'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121091',
#   '幼兒教育學系',
#   'N 職',
#   'M 碩士',
#   '65',
#   '3',
#   '62'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131085',
#   '數理教育研究所',
#   'D 日',
#   'M 碩士',
#   '76',
#   '42',
#   '34'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131085',
#   '數理教育研究所',
#   'N 職',
#   'M 碩士',
#   '76',
#   '20',
#   '56'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131085',
#   '數理教育研究所數學教育教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '4',
#   '1',
#   '3'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131105',
#   '英語教學系',
#   'D 日',
#   'M 碩士',
#   '36',
#   '3',
#   '33'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131105',
#   '英語教學系',
#   'D 日',
#   'B 學士',
#   '174',
#   '51',
#   '123'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141098',
#   '藝術與設計學系美勞教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '53',
#   '2',
#   '51'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141127',
#   '運動科學系',
#   'D 日',
#   'M 碩士',
#   '48',
#   '22',
#   '26'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141127',
#   '運動科學系',
#   'D 日',
#   'B 學士',
#   '198',
#   '113',
#   '85'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141127',
#   '運動科學系',
#   'N 職',
#   'M 碩士',
#   '47',
#   '22',
#   '25'],
#  ['111',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199130',
#   '竹師教育學院跨領域STEAM教育碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '29',
#   '8',
#   '21'],
#  ['111',
#   '一般',
#   '公立',
#   '0003',
#   '國立臺灣大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131001',
#   '華語教學碩士學位學程',
#   'D 日',
#   'M 碩士',
#   '59',
#   '7',
#   '52'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'D 博士',
#   '67',
#   '32',
#   '35'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'M 碩士',
#   '78',
#   '23',
#   '55'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'B 學士',
#   '267',
#   '89',
#   '178'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系教育管理與課程教學領導碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '17',
#   '2',
#   '15'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系教育領導與政策碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '85',
#   '18',
#   '67'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系課程與教學領導碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '3',
#   '2',
#   '1'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系學校行政教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '2',
#   '2',
#   '-'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111088',
#   '科學—科技—工程—數學整合教育國際博士學位學程',
#   'D 日',
#   'D 博士',
#   '2',
#   '1',
#   '1'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113018',
#   '特殊教育學系',
#   'D 日',
#   'D 博士',
#   '31',
#   '11',
#   '20'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113018',
#   '特殊教育學系',
#   'D 日',
#   'M 碩士',
#   '68',
#   '17',
#   '51'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113018',
#   '特殊教育學系',
#   'D 日',
#   'B 學士',
#   '170',
#   '40',
#   '130'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113018',
#   '特殊教育學系',
#   'N 職',
#   'M 碩士',
#   '84',
#   '15',
#   '69'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113018',
#   '特殊教育學系身心障礙特教教學碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '2',
#   '-',
#   '2'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114019',
#   '教育政策與行政研究所',
#   'D 日',
#   'M 碩士',
#   '50',
#   '13',
#   '37'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115002',
#   '課程與教學研究所',
#   'D 日',
#   'D 博士',
#   '34',
#   '14',
#   '20'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115002',
#   '課程與教學研究所',
#   'D 日',
#   'M 碩士',
#   '48',
#   '10',
#   '38'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115006',
#   '科學教育研究所',
#   'D 日',
#   'D 博士',
#   '27',
#   '14',
#   '13'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115006',
#   '科學教育研究所',
#   'D 日',
#   'M 碩士',
#   '59',
#   '33',
#   '26'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01116 教育科技細學類',
#   '01116014',
#   '資訊教育研究所',
#   'D 日',
#   'D 博士',
#   '24',
#   '9',
#   '15'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01116 教育科技細學類',
#   '01116014',
#   '資訊教育研究所',
#   'D 日',
#   'M 碩士',
#   '71',
#   '27',
#   '44'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01116 教育科技細學類',
#   '01116079',
#   '學習科學學士學位學程',
#   'D 日',
#   'B 學士',
#   '71',
#   '33',
#   '38'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01118 技職教育細學類',
#   '01118010',
#   '工業教育學系',
#   'D 日',
#   'M 碩士',
#   '88',
#   '59',
#   '29'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131004',
#   '公民教育與活動領導學系',
#   'D 日',
#   'D 博士',
#   '49',
#   '24',
#   '25'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131004',
#   '公民教育與活動領導學系',
#   'D 日',
#   'M 碩士',
#   '74',
#   '24',
#   '50'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131004',
#   '公民教育與活動領導學系',
#   'D 日',
#   'B 學士',
#   '363',
#   '144',
#   '219'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131004',
#   '公民教育與活動領導學系活動領導碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '48',
#   '15',
#   '33'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131004',
#   '公民教育與活動領導學系學生事務碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '36',
#   '13',
#   '23'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131009',
#   '社會教育學系',
#   'D 日',
#   'D 博士',
#   '33',
#   '8',
#   '25'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131009',
#   '社會教育學系',
#   'D 日',
#   'M 碩士',
#   '79',
#   '15',
#   '64'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131009',
#   '社會教育學系',
#   'D 日',
#   'B 學士',
#   '228',
#   '53',
#   '175'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131009',
#   '社會教育學系社會教育與文化行政碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '46',
#   '4',
#   '42'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131017',
#   '健康促進與衛生教育學系',
#   'D 日',
#   'M 碩士',
#   '67',
#   '21',
#   '46'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131017',
#   '健康促進與衛生教育學系',
#   'D 日',
#   'B 學士',
#   '179',
#   '48',
#   '131'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141007',
#   '人類發展與家庭學系',
#   'D 日',
#   'D 博士',
#   '32',
#   '3',
#   '29'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141007',
#   '人類發展與家庭學系',
#   'D 日',
#   'M 碩士',
#   '72',
#   '8',
#   '64'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141007',
#   '人類發展與家庭學系',
#   'D 日',
#   'B 學士',
#   '293',
#   '39',
#   '254'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141007',
#   '人類發展與家庭學系幼兒教育碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '1',
#   '-',
#   '1'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141010',
#   '工業教育學系',
#   'D 日',
#   'D 博士',
#   '33',
#   '20',
#   '13'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141010',
#   '工業教育學系',
#   'D 日',
#   'B 學士',
#   '125',
#   '114',
#   '11'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141010',
#   '工業教育學系技職教育行政碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '34',
#   '16',
#   '18'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141010',
#   '工業教育學系技職教育數位碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '25',
#   '15',
#   '10'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141010',
#   '工業教育學系科技應用管理碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '52',
#   '28',
#   '24'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141013',
#   '環境教育研究所',
#   'D 日',
#   'D 博士',
#   '23',
#   '13',
#   '10'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141013',
#   '環境教育研究所',
#   'D 日',
#   'M 碩士',
#   '49',
#   '21',
#   '28'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141017',
#   '健康促進與衛生教育學系',
#   'D 日',
#   'D 博士',
#   '54',
#   '25',
#   '29'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141017',
#   '健康促進與衛生教育學系健康促進與衛生教育碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '103',
#   '12',
#   '91'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141087',
#   '體育與運動科學系',
#   'D 日',
#   'D 博士',
#   '114',
#   '66',
#   '48'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141087',
#   '體育與運動科學系',
#   'D 日',
#   'M 碩士',
#   '157',
#   '92',
#   '65'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141087',
#   '體育與運動科學系',
#   'D 日',
#   'B 學士',
#   '261',
#   '157',
#   '104'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141087',
#   '體育與運動科學系運動科學碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '33',
#   '18',
#   '15'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141087',
#   '體育與運動科學系體育行政教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '13',
#   '9',
#   '4'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199021',
#   '教育學院學士班',
#   'D 日',
#   'B 學士',
#   '46',
#   '8',
#   '38'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199021',
#   '教育學院創造力發展碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '102',
#   '15',
#   '87'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199022',
#   '科技應用與人力資源發展學系',
#   'D 日',
#   'D 博士',
#   '40',
#   '23',
#   '17'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199022',
#   '科技應用與人力資源發展學系',
#   'D 日',
#   'M 碩士',
#   '81',
#   '29',
#   '52'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199022',
#   '科技應用與人力資源發展學系',
#   'D 日',
#   'B 學士',
#   '256',
#   '139',
#   '117'],
#  ['111',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199022',
#   '科技應用與人力資源發展學系人力資源發展碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '85',
#   '17',
#   '68'],
#  ['111',
#   '一般',
#   '公立',
#   '0005',
#   '國立成功大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111103',
#   '教育研究所',
#   'D 日',
#   'D 博士',
#   '31',
#   '14',
#   '17'],
#  ['111',
#   '一般',
#   '公立',
#   '0005',
#   '國立成功大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111103',
#   '教育研究所',
#   'D 日',
#   'M 碩士',
#   '61',
#   '13',
#   '48'],
#  ['111',
#   '一般',
#   '公立',
#   '0006',
#   '國立中興大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教師專業發展研究所',
#   'D 日',
#   'M 碩士',
#   '34',
#   '10',
#   '24'],
#  ['111',
#   '一般',
#   '公立',
#   '0007',
#   '國立陽明交通大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育研究所',
#   'D 日',
#   'D 博士',
#   '32',
#   '10',
#   '22'],
#  ['111',
#   '一般',
#   '公立',
#   '0007',
#   '國立陽明交通大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育研究所',
#   'D 日',
#   'M 碩士',
#   '79',
#   '21',
#   '58'],
#  ['111',
#   '一般',
#   '公立',
#   '0007',
#   '國立陽明交通大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131002',
#   '英語教學研究所',
#   'D 日',
#   'M 碩士',
#   '31',
#   '7',
#   '24'],
#  ['111',
#   '一般',
#   '公立',
#   '0008',
#   '國立中央大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115001',
#   '學習與教學研究所',
#   'D 日',
#   'D 博士',
#   '26',
#   '5',
#   '21'],
#  ['111',
#   '一般',
#   '公立',
#   '0008',
#   '國立中央大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115001',
#   '學習與教學研究所',
#   'D 日',
#   'M 碩士',
#   '34',
#   '8',
#   '26'],
#  ['111',
#   '一般',
#   '公立',
#   '0009',
#   '國立中山大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育研究所',
#   'D 日',
#   'D 博士',
#   '50',
#   '17',
#   '33'],
#  ['111',
#   '一般',
#   '公立',
#   '0009',
#   '國立中山大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育研究所',
#   'D 日',
#   'M 碩士',
#   '36',
#   '11',
#   '25'],
#  ['111',
#   '一般',
#   '公立',
#   '0009',
#   '國立中山大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育研究所',
#   'N 職',
#   'M 碩士',
#   '61',
#   '16',
#   '45'],
#  ['111',
#   '一般',
#   '公立',
#   '0009',
#   '國立中山大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111072',
#   '教育與人類發展研究全英語博士學位學程',
#   'D 日',
#   'D 博士',
#   '19',
#   '6',
#   '13'],
#  ['111',
#   '一般',
#   '公立',
#   '0009',
#   '國立中山大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111072',
#   '教育與人類發展研究全英語碩士學位學程',
#   'D 日',
#   'M 碩士',
#   '9',
#   '1',
#   '8'],
#  ['111',
#   '一般',
#   '公立',
#   '0012',
#   '國立臺灣海洋大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所',
#   'D 日',
#   'M 碩士',
#   '62',
#   '26',
#   '36'],
#  ['111',
#   '一般',
#   '公立',
#   '0012',
#   '國立臺灣海洋大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所',
#   'N 職',
#   'M 碩士',
#   '95',
#   '19',
#   '76'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學研究所教育學博士班',
#   'D 日',
#   'D 博士',
#   '33',
#   '20',
#   '13'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學研究所課程博士班',
#   'D 日',
#   'D 博士',
#   '27',
#   '14',
#   '13'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學研究所課程與教學碩士班',
#   'D 日',
#   'M 碩士',
#   '22',
#   '14',
#   '8'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學研究所教育學碩士班',
#   'D 日',
#   'M 碩士',
#   '26',
#   '4',
#   '22'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學研究所教育學碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '93',
#   '15',
#   '78'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112005',
#   '成人及繼續教育學系',
#   'D 日',
#   'D 博士',
#   '40',
#   '13',
#   '27'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112005',
#   '成人及繼續教育學系',
#   'D 日',
#   'M 碩士',
#   '44',
#   '10',
#   '34'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112005',
#   '成人及繼續教育學系高齡者教育碩士班',
#   'D 日',
#   'M 碩士',
#   '42',
#   '10',
#   '32'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112005',
#   '成人及繼續教育學系',
#   'D 日',
#   'B 學士',
#   '111',
#   '35',
#   '76'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112005',
#   '成人及繼續教育學系',
#   'N 職',
#   'M 碩士',
#   '94',
#   '11',
#   '83'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114007',
#   '教育領導與管理發展國際博士學位學程',
#   'D 日',
#   'D 博士',
#   '9',
#   '2',
#   '7'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114007',
#   '教育領導與管理發展國際碩士學位學程',
#   'D 日',
#   'M 碩士',
#   '20',
#   '8',
#   '12'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114081',
#   '教育專業與學校領導數位學習碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '4',
#   '2',
#   '2'],
#  ['111',
#   '一般',
#   '公立',
#   '0013',
#   '國立中正大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01116 教育科技細學類',
#   '01116008',
#   '教學專業發展數位學習碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '84',
#   '13',
#   '71'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'D 博士',
#   '84',
#   '34',
#   '50'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'M 碩士',
#   '62',
#   '19',
#   '43'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'B 學士',
#   '157',
#   '53',
#   '104'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系生命教育碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '83',
#   '8',
#   '75'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系課程與教學碩士班(夜間班)',
#   'N 職',
#   'M 碩士',
#   '43',
#   '3',
#   '40'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系學校行政領導碩士班',
#   'N 職',
#   'M 碩士',
#   '11',
#   '4',
#   '7'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111059',
#   '運動與健康現役軍人營區碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '3',
#   '3',
#   '-'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112009',
#   '成人教育研究所',
#   'D 日',
#   'D 博士',
#   '65',
#   '32',
#   '33'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112009',
#   '成人教育研究所',
#   'D 日',
#   'M 碩士',
#   '60',
#   '9',
#   '51'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112009',
#   '成人教育研究所組織發展與領導碩士在職專班(夜間班)',
#   'N 職',
#   'M 碩士',
#   '63',
#   '27',
#   '36'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113010',
#   '特殊教育學系特殊教育博士班',
#   'D 日',
#   'D 博士',
#   '28',
#   '13',
#   '15'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113010',
#   '特殊教育學系特殊教育碩士班',
#   'D 日',
#   'M 碩士',
#   '35',
#   '7',
#   '28'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113010',
#   '特殊教育學系聽力學與語言治療碩士班',
#   'D 日',
#   'M 碩士',
#   '51',
#   '7',
#   '44'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113010',
#   '特殊教育學系',
#   'D 日',
#   'B 學士',
#   '151',
#   '35',
#   '116'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113010',
#   '特殊教育學系特殊教育教學碩士班',
#   'N 職',
#   'M 碩士',
#   '16',
#   '4',
#   '12'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114054',
#   '高階教育經營與行政管理馬來西亞境外碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '28',
#   '13',
#   '15'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141003',
#   '工業科技教育學系',
#   'D 日',
#   'D 博士',
#   '34',
#   '22',
#   '12'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141003',
#   '工業科技教育學系',
#   'D 日',
#   'M 碩士',
#   '35',
#   '16',
#   '19'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141003',
#   '工業科技教育學系',
#   'D 日',
#   'B 學士',
#   '155',
#   '111',
#   '44'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141003',
#   '工業科技教育學系工業(生活)科技教學碩士班(暑期班)',
#   'N 職',
#   'M 碩士',
#   '83',
#   '27',
#   '56'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141003',
#   '工業科技教育學系科技教育碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '44',
#   '27',
#   '17'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141005',
#   '體育學系',
#   'D 日',
#   'M 碩士',
#   '65',
#   '39',
#   '26'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141005',
#   '體育學系',
#   'D 日',
#   'B 學士',
#   '211',
#   '138',
#   '73'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141005',
#   '體育學系體育教學碩士班(夜間班)',
#   'N 職',
#   'M 碩士',
#   '4',
#   '3',
#   '1'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141005',
#   '體育學系體育碩士在職專班(週末班)',
#   'N 職',
#   'M 碩士',
#   '74',
#   '45',
#   '29'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141006',
#   '科學教育暨環境教育研究所科學教育博士班',
#   'D 日',
#   'D 博士',
#   '48',
#   '28',
#   '20'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141006',
#   '科學教育暨環境教育研究所',
#   'D 日',
#   'M 碩士',
#   '71',
#   '36',
#   '35'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141006',
#   '科學教育暨環境教育研究所碩士在職現役軍人營區專班',
#   'N 職',
#   'M 碩士',
#   '32',
#   '26',
#   '6'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199011',
#   '性別教育博士學位學程',
#   'D 日',
#   'D 博士',
#   '23',
#   '6',
#   '17'],
#  ['111',
#   '一般',
#   '公立',
#   '0014',
#   '國立高雄師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199011',
#   '性別教育研究所',
#   'D 日',
#   'M 碩士',
#   '48',
#   '14',
#   '34'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所',
#   'D 日',
#   'D 博士',
#   '32',
#   '16',
#   '16'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所',
#   'D 日',
#   'M 碩士',
#   '63',
#   '20',
#   '43'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所教育創新與人力發展碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '69',
#   '19',
#   '50'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所教育與學校行政碩士學位班',
#   'N 職',
#   'M 碩士',
#   '4',
#   '2',
#   '2'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所教育學回流碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '42',
#   '12',
#   '30'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111002',
#   '教育研究所教育學暨學校行政馬來西亞境外碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '1',
#   '1',
#   '-'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113012',
#   '特殊教育學系',
#   'D 日',
#   'D 博士',
#   '24',
#   '7',
#   '17'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113012',
#   '特殊教育學系資賦優異教育碩士班',
#   'D 日',
#   'M 碩士',
#   '12',
#   '3',
#   '9'],
#  ['111',
#   '一般',
#   '公立',
#   '0015',
#   '國立彰化師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113012',
#   '特殊教育學系',
#   'D 日',
#   'M 碩士',
#   '42',
#   '12',
#   '30'],
#  ['111',
#   '一般',
# ...
#  ['110',
#   '技職',
#   '私立',
#   '1031',
#   '輔英科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121035',
#   '幼兒保育暨產業系',
#   'N 修',
#   'C 二技',
#   '116',
#   '7',
#   '109'],
#  ['110',
#   '技職',
#   '私立',
#   '1047',
#   '中臺科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111009',
#   '文教事業經營研究所',
#   'D 日',
#   'M 碩士',
#   '21',
#   '4',
#   '17'],
#  ['110',
#   '技職',
#   '私立',
#   '1047',
#   '中臺科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111009',
#   '文教事業經營研究所',
#   'N 職',
#   'M 碩士',
#   '63',
#   '14',
#   '49'],
#  ['110',
#   '技職',
#   '私立',
#   '1047',
#   '中臺科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121001',
#   '兒童教育暨事業經營系',
#   'D 日',
#   'B 四技',
#   '259',
#   '12',
#   '247'],
#  ['110',
#   '技職',
#   '私立',
#   '1047',
#   '中臺科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121001',
#   '兒童教育暨事業經營系',
#   'N 修',
#   'B 四技',
#   '130',
#   '3',
#   '127'],
#  ['110',
#   '技職',
#   '私立',
#   '1047',
#   '中臺科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121001',
#   '兒童教育暨事業經營系',
#   'N 修',
#   'C 二技',
#   '226',
#   '14',
#   '212'],
#  ['110',
#   '一般',
#   '私立',
#   '1048',
#   '亞洲大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121001',
#   '幼兒教育學系',
#   'D 日',
#   'M 碩士',
#   '7',
#   '2',
#   '5'],
#  ['110',
#   '一般',
#   '私立',
#   '1048',
#   '亞洲大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121001',
#   '幼兒教育學系',
#   'D 日',
#   'B 學士',
#   '375',
#   '24',
#   '351'],
#  ['110',
#   '一般',
#   '私立',
#   '1058',
#   '明道大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115001',
#   '課程與教學研究所',
#   'D 日',
#   'M 碩士',
#   '19',
#   '5',
#   '14'],
#  ['110',
#   '一般',
#   '私立',
#   '1058',
#   '明道大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115001',
#   '課程與教學研究所',
#   'N 職',
#   'M 碩士',
#   '16',
#   '6',
#   '10'],
#  ['110',
#   '技職',
#   '私立',
#   '1065',
#   '吳鳳科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121023',
#   '幼兒保育系',
#   'D 日',
#   'B 四技',
#   '122',
#   '8',
#   '114'],
#  ['110',
#   '技職',
#   '私立',
#   '1065',
#   '吳鳳科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121023',
#   '幼兒保育系',
#   'N 修',
#   'C 二技',
#   '168',
#   '12',
#   '156'],
#  ['110',
#   '技職',
#   '私立',
#   '1065',
#   '吳鳳科技大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121023',
#   '幼兒保育科',
#   'N 修',
#   '2 二專',
#   '59',
#   '4',
#   '55'],
#  ['110',
#   '一般',
#   '私立',
#   '1067',
#   '台灣首府大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育研究所',
#   'D 日',
#   'M 碩士',
#   '9',
#   '-',
#   '9'],
#  ['110',
#   '一般',
#   '私立',
#   '1067',
#   '台灣首府大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121002',
#   '幼兒教育學系',
#   'D 日',
#   'M 碩士',
#   '21',
#   '1',
#   '20'],
#  ['110',
#   '一般',
#   '私立',
#   '1067',
#   '台灣首府大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121002',
#   '幼兒教育學系',
#   'D 日',
#   'B 學士',
#   '78',
#   '11',
#   '67'],
#  ['110',
#   '技職',
#   '私立',
#   '1075',
#   '文藻外語大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131001',
#   '華語文教學研究所',
#   'D 日',
#   'M 碩士',
#   '56',
#   '11',
#   '45'],
#  ['110',
#   '技職',
#   '私立',
#   '1075',
#   '文藻外語大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131002',
#   '外語教學系',
#   'D 日',
#   'B 四技',
#   '410',
#   '109',
#   '301'],
#  ['110',
#   '技職',
#   '私立',
#   '1075',
#   '文藻外語大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131002',
#   '外語教學系外語文教事業發展碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '27',
#   '3',
#   '24'],
#  ['110',
#   '一般',
#   '私立',
#   '1196',
#   '法鼓文理學院',
#   '01 教育領域',
#   '011 教育學門',
#   '0119 其他教育學類',
#   '01199 其他教育細學類',
#   '01199001',
#   '生命教育碩士學位學程',
#   'D 日',
#   'M 碩士',
#   '119',
#   '22',
#   '97'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'D 博士',
#   '98',
#   '29',
#   '69'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'M 碩士',
#   '44',
#   '8',
#   '36'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'B 學士',
#   '257',
#   '62',
#   '195'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113029',
#   '特殊教育學系',
#   'D 日',
#   'M 碩士',
#   '134',
#   '16',
#   '118'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113029',
#   '特殊教育學系',
#   'D 日',
#   'B 學士',
#   '171',
#   '31',
#   '140'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113029',
#   '特殊教育學系',
#   'N 職',
#   'M 碩士',
#   '57',
#   '2',
#   '55'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114035',
#   '教育行政與評鑑研究所',
#   'D 日',
#   'D 博士',
#   '49',
#   '19',
#   '30'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114035',
#   '教育行政與評鑑研究所',
#   'D 日',
#   'M 碩士',
#   '42',
#   '8',
#   '34'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114035',
#   '教育行政與評鑑研究所',
#   'N 職',
#   'M 碩士',
#   '95',
#   '26',
#   '69'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115036',
#   '學習與媒材設計學系課程與教學碩士班',
#   'D 日',
#   'M 碩士',
#   '41',
#   '4',
#   '37'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115036',
#   '學習與媒材設計學系課程與教學碩士學位班',
#   'N 職',
#   'M 碩士',
#   '4',
#   '-',
#   '4'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115036',
#   '學習與媒材設計學系課程與教學碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '87',
#   '13',
#   '74'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01116 教育科技細學類',
#   '01116036',
#   '學習與媒材設計學系',
#   'D 日',
#   'B 學士',
#   '169',
#   '39',
#   '130'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121027',
#   '幼兒教育學系',
#   'D 日',
#   'M 碩士',
#   '91',
#   '10',
#   '81'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121027',
#   '幼兒教育學系',
#   'D 日',
#   'B 學士',
#   '332',
#   '28',
#   '304'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121027',
#   '幼兒教育學系',
#   'N 職',
#   'M 碩士',
#   '81',
#   '3',
#   '78'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121027',
#   '幼兒教育學系幼教教學碩士學位班',
#   'N 職',
#   'M 碩士',
#   '4',
#   '-',
#   '4'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131017',
#   '英語教學系',
#   'D 日',
#   'M 碩士',
#   '36',
#   '7',
#   '29'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131017',
#   '英語教學系',
#   'D 日',
#   'B 學士',
#   '144',
#   '40',
#   '104'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141025',
#   '體育學系',
#   'D 日',
#   'M 碩士',
#   '40',
#   '24',
#   '16'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141025',
#   '體育學系',
#   'D 日',
#   'B 學士',
#   '219',
#   '139',
#   '80'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141025',
#   '體育學系',
#   'N 職',
#   'M 碩士',
#   '59',
#   '31',
#   '28'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141025',
#   '體育學系體育教學碩士學位班',
#   'N 職',
#   'M 碩士',
#   '52',
#   '18',
#   '34'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141026',
#   '運動教育研究所',
#   'D 日',
#   'M 碩士',
#   '39',
#   '14',
#   '25'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141026',
#   '運動教育研究所',
#   'N 職',
#   'M 碩士',
#   '38',
#   '14',
#   '24'],
#  ['110',
#   '一般',
#   '公立',
#   '3002',
#   '臺北市立大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141030',
#   '身心障礙者轉銜及休閒教育碩士學位學程',
#   'D 日',
#   'M 碩士',
#   '38',
#   '10',
#   '28'],
#  ['109',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'D 博士',
#   '113',
#   '50',
#   '63'],
#  ['109',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'M 碩士',
#   '28',
#   '9',
#   '19'],
#  ['109',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'B 學士',
#   '225',
#   '72',
#   '153'],
#  ['109',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114005',
#   '教育行政與政策研究所',
#   'D 日',
#   'M 碩士',
#   '45',
#   '15',
#   '30'],
#  ['109',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01114 教育行政細學類',
#   '01114006',
#   '學校行政碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '80',
#   '25',
#   '55'],
#  ['109',
#   '一般',
#   '公立',
#   '0001',
#   '國立政治大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121004',
#   '幼兒教育研究所',
#   'D 日',
#   'M 碩士',
#   '39',
#   '3',
#   '36'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系',
#   'D 日',
#   'D 博士',
#   '57',
#   '19',
#   '38'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系',
#   'D 日',
#   'M 碩士',
#   '129',
#   '22',
#   '107'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系馬來西亞境外碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '1',
#   '1',
#   '-'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系教育行政碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '64',
#   '9',
#   '55'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111084',
#   '教育與學習科技學系課程與教學碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '130',
#   '23',
#   '107'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111112',
#   '竹師教育學院學士班',
#   'D 日',
#   'B 學士',
#   '106',
#   '43',
#   '63'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01112 成人教育細學類',
#   '01112083',
#   '人力資源與數位學習科技研究所',
#   'D 日',
#   'M 碩士',
#   '3',
#   '1',
#   '2'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113095',
#   '特殊教育學系',
#   'D 日',
#   'M 碩士',
#   '53',
#   '4',
#   '49'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113095',
#   '特殊教育學系',
#   'D 日',
#   'B 學士',
#   '152',
#   '35',
#   '117'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01113 特殊教育細學類',
#   '01113110',
#   '學前特殊教育碩士在職學位學程',
#   'N 職',
#   'M 碩士',
#   '33',
#   '1',
#   '32'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01115 課程與教學細學類',
#   '01115124',
#   '華德福教育碩士在職學位學程',
#   'N 職',
#   'M 碩士',
#   '16',
#   '1',
#   '15'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121091',
#   '幼兒教育學系',
#   'D 日',
#   'M 碩士',
#   '63',
#   '4',
#   '59'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121091',
#   '幼兒教育學系',
#   'D 日',
#   'B 學士',
#   '186',
#   '20',
#   '166'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121091',
#   '幼兒教育學系',
#   'N 職',
#   'M 碩士',
#   '60',
#   '4',
#   '56'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0112 幼兒師資教育學類',
#   '01121 幼兒師資教育細學類',
#   '01121091',
#   '幼兒教育學系幼兒園教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '1',
#   '-',
#   '1'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131084',
#   '教育與學習科技學系',
#   'D 日',
#   'B 學士',
#   '190',
#   '54',
#   '136'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131085',
#   '數理教育研究所',
#   'D 日',
#   'M 碩士',
#   '71',
#   '33',
#   '38'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131085',
#   '數理教育研究所',
#   'N 職',
#   'M 碩士',
#   '78',
#   '24',
#   '54'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131085',
#   '數理教育研究所科學教育教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '8',
#   '2',
#   '6'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131085',
#   '數理教育研究所數學教育教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '7',
#   '3',
#   '4'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131105',
#   '英語教學系',
#   'D 日',
#   'M 碩士',
#   '35',
#   '5',
#   '30'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131105',
#   '英語教學系',
#   'D 日',
#   'B 學士',
#   '153',
#   '43',
#   '110'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141098',
#   '藝術與設計學系美勞教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '46',
#   '3',
#   '43'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141127',
#   '運動科學系',
#   'D 日',
#   'M 碩士',
#   '52',
#   '20',
#   '32'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141127',
#   '運動科學系',
#   'D 日',
#   'B 學士',
#   '176',
#   '113',
#   '63'],
#  ['109',
#   '一般',
#   '公立',
#   '0002',
#   '國立清華大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0114 專業科目師資教育學類',
#   '01141 專業科目師資教育細學類',
#   '01141127',
#   '運動科學系',
#   'N 職',
#   'M 碩士',
#   '54',
#   '31',
#   '23'],
#  ['109',
#   '一般',
#   '公立',
#   '0003',
#   '國立臺灣大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0113 普通科目師資教育學類',
#   '01131 普通科目師資教育細學類',
#   '01131001',
#   '華語教學碩士學位學程',
#   'D 日',
#   'M 碩士',
#   '51',
#   '4',
#   '47'],
#  ['109',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'D 博士',
#   '79',
#   '34',
#   '45'],
#  ['109',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'M 碩士',
#   '70',
#   '21',
#   '49'],
#  ['109',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系',
#   'D 日',
#   'B 學士',
#   '267',
#   '77',
#   '190'],
#  ['109',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系教育管理與課程教學領導碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '25',
#   '4',
#   '21'],
#  ['109',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系教育領導與政策碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '68',
#   '16',
#   '52'],
#  ['109',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系課程與教學領導碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '23',
#   '6',
#   '17'],
#  ['109',
#   '一般',
#   '公立',
#   '0004',
#   '國立臺灣師範大學',
#   '01 教育領域',
#   '011 教育學門',
#   '0111 教育學學類',
#   '01111 綜合教育細學類',
#   '01111001',
#   '教育學系學校行政教師碩士在職專班',
#   'N 職',
#   'M 碩士',
#   '6',
#   '3',
#   '3'],
#  ...]

# %%
import csv

with open('result.csv', 'w', newline='',encoding="utf8") as csvfile:
  writer = csv.writer(csvfile)

  # 寫入二維表格
  writer.writerows(table)

# %%
# 補足1157頁沒完成的部分

import csv

with open('result.csv', 'a', newline='', encoding="utf8") as csvfile:
    writer = csv.writer(csvfile)

    # 寫入二維表格
    writer.writerows([['87', '一般', '公立', '3102', '臺北市立體育學院', '01 教育領域', '011 教育學門',
                     "0114 專業科目師資教育學類", '01141 專業科目師資教育細學類', '140315 體育學系', 'D 日', '5 五專', '168', '104', '64']])
