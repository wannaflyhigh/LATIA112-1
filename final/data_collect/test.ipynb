# %%
from math import floor
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import chromedriver_autoinstaller_fix
from time import sleep
import requests as rq
import pandas as pd
from bs4 import BeautifulSoup as soup
from selenium.webdriver.chrome.options import Options
from lxml import etree
import time

chromedriver_autoinstaller_fix.install()

# %%
driver = webdriver.Chrome()

url = "https://www.junyiacademy.org/junyi-science/science-high/junyi-biology/"
url_short = "https://www.junyiacademy.org/"
html = driver.get(url)
time.sleep(2)
sp = soup(driver.page_source, "lxml")

data_column_name = ["單元", "課程名稱","網址"]


def get_data_address():
    data = []
    row = []
    sp = soup(driver.page_source, "html.parser")

    # Check if the tbody element with class "table_bottom" exists
    table = sp.find(
        "div",
        class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-12 MuiGrid-grid-lg-9 css-1hjwhii",
    )
    if table:
        div_tags = table.find_all("div", class_="MuiBox-root css-bdhjb8")
        for div_tag in div_tags:
            element_id = div_tag.get("id")[11:]
            td_tags = div_tag.find_all("div", class_="css-1fxvrsu")
            element_id = element_id.strip("'")
            row.append(element_id)
            for td_tag in td_tags:
                row.append(td_tag.text)
                data.append(row)
                row = []
    return data


def get_data(columns_name, now_page):
    data = []
    row = []
    sp = soup(driver.page_source, "html.parser")

    table = sp.find(
        "ul",
        class_="MuiList-root MuiList-padding css-1ontqvh",
    )
    if table:
        li_tags = table.find_all("li", class_="MuiListItem-container css-79elbk")
        for li_tag in li_tags:
            # judge_div_tags = li_tag.find_all(
            #     "div", class_="MuiListItemAvatar-root css-a5kqs7"
            # )
            # print(judge_div_tags)
            # for i in judge_div_tags:
            #     judge_div_tag = i.find_all("img", "MuiAvatar-img css-1hy9t21")
            #     print(judge_div_tag)
            #     for z in judge_div_tag:
            #         element = driver.execute_script(
            #             "return arguments[0].getAttribute('alt');", z
            #         )
            # if element != "video":
            #     continue
            div_tags = li_tag.find_all("div", class_="MuiListItemText-root css-1u7dzma")
            for div_tag in div_tags:
                span_tags = div_tag.find_all(
                    "span", class_="MuiTypography-root MuiTypography-body1 css-37h3rr"
                )
                for span_tag in span_tags:
                    row.append(columns_name)
                    row.append(span_tag.text[:-7])
                    data.append(row)
                    row = []
    print(data)
    return data


def get_data_video_web():
    sp = soup(driver.page_source, "html.parser")
    button_element = driver.find_element(
        By.XPATH,
        "/html/body/div[1]/div[4]/div[1]/div[2]/article/div/div/div[1]/div/div[2]/div[2]/ul/li[1]/div[1]",
    )
    button_element.click()


def get_data_web(data, count):
    sp = soup(driver.page_source, "html.parser")

    table = sp.find(
        "div",
        class_="nav-page-content",
    )
    if table:
        li_tags = table.find_all("div", class_="nav-pane")
        for li_tag in li_tags:
            ul_element = li_tag.find("ul")
            li_elements = ul_element.find_all("li")
            for li_element in li_elements:
                link_element = li_element.find("a")
                if link_element:
                    href_value = link_element.get("href")
                    data[count].append(url_short + href_value)
                    count += 1
    return data, count


def next_page(html_port):
    driver.get(url + html_port)
    time.sleep(5)


address = get_data_address()
data = []
now_page = 0
while True:
    next_page(address[now_page][0])
    data.extend(get_data(address[now_page][1], now_page))
    if now_page == len(address) - 1:
        print("This is the last page ( •̀ ω •́ )✧")
        break
    else:
        now_page += 1
now_page = 0
count = 0
while True:
    next_page(address[now_page][0])
    get_data_video_web()
    time.sleep(3)
    data_sp = get_data_web(data, count)
    data = data_sp[0]
    count = data_sp[1]
    if now_page == len(address) - 1:
        print("This is the last page ( •̀ ω •́ )✧")
        break
    else:
        now_page += 1

print(data)
# Out:
# [['生命的特性', '生命現象概論'], ['生命的特性', '生命現象 代謝'], ['生命的特性', '從肥胖看生命現象之生長現象'], ['生命的特性', '生命現象 感應與運動'], ['生命的特性', '生命現象 繁殖'], ['生命的特性', ''], ['生命的特性', '細胞的發現與細胞學說'], ['生命的特性', '細胞的大小(內有有趣的網站)'], ['生命的特性', '科學方法(歌)'], ['生命的特性', '組成細胞的分子概論'], ['生命的特性', '組成細胞的分子 水'], ['生命的特性', '組成細胞的分子 礦物質'], ['生命的特性', '組成細胞的分子 醣類'], ['生命的特性', '組成細胞的分子 脂質'], ['生命的特性', '組成細胞的分子 蛋白質'], ['生命的特性', '組成細胞的分子 核酸'], ['生命的特性', ''], ['生命的特性', '從房間的概念看細胞'], ['生命的特性', '真核細胞與原核細胞的比較'], ['生命的特性', '真核細胞的基本構造 細胞膜與細胞壁'], ['生命的特性', '真核細胞的基本構造 細胞核'], ['生命的特性', '真核細胞的基本構造 細胞質與胞器的簡介'], ['生命的特性', '胞器介紹 非膜狀構造：核糖體與中心粒'], ['生命的特性', '胞器介紹 單層膜狀胞器：內質網、高基氏體、液泡'], ['生命的特性', '胞器介紹 雙層膜狀胞器：粒腺體與葉綠體'], ['生命的特性', ''], ['生命的特性', ''], ['生命的特性', '半透膜的定義與細胞膜脂雙層的通透性'], ['生命的特性', '被動運輸 簡單擴散'], ['生命的特性', '被動運輸 促進擴散'], ['生命的特性', '主動運輸'], ['生命的特性', '滲透作用'], ['生命的特性', '滲透作用對細胞的影響'], ['生命的特性', '細胞中的化學反應'], ['生命的特性', '酵素'], ['生命的特性', ''], ['生命的特性', 'ATP的結構與功能'], ['生命的特性', 'ATP的水解與合成'], ['生命的特性', '光合作用的場所-葉綠體'], ['生命的特性', '光合作用-光反應與碳反應'], ['生命的特性', 'NADPH-光反應與暗反應之間的橋梁'], ['生命的特性', '呼吸作用與發酵作用1'], ['生命的特性', '呼吸作用與發酵作用2'], ['生命的特性', ''], ['生命的特性', '細胞生']]
# [['遺傳', '染色體的發現與形態'], ['遺傳', '染色體的數目與類型(性、體染色體；同源、姐妹染色體)'], ['遺傳', '有絲分裂(請練習繪製示意圖)'], ['遺傳', '有絲分裂的過程與相關構造'], ['遺傳', '動植物細胞有絲分裂的比較'], ['遺傳', ''], ['遺傳', '為何要減數分裂-單倍體-雙倍體'], ['遺傳', '減數分裂(請練習繪製示意圖)'], ['遺傳', '減數分裂的階段與套數問題'], ['遺傳', '聯會-減數分裂的特有現象'], ['遺傳', '減數分裂與有絲分裂的比較'], ['遺傳', '人體的減數分裂 精子卵子的產生'], ['遺傳', ''], ['遺傳', '細'], ['遺傳', ''], ['遺傳', '【專欄】無合成分裂：斑馬魚難以察覺'], ['遺傳', '志玲姐姐的雙眼皮-遺傳學簡介'], ['遺傳', '性狀與表徵；孟德爾與豌豆'], ['遺傳', '單性雜交實驗-過程與結果'], ['遺傳', '豌豆實驗的「互交」'], ['遺傳', '分離律-單性雜交實驗結論'], ['遺傳', '兩性雜交實驗-過程與結果'], ['遺傳', '獨立分配律-兩性雜交實驗結論'], ['遺傳', '基因、基因型、表現型'], ['遺傳', '用基因與染色體解釋分離律與獨立分配律'], ['遺傳', '試交 確認第一子代的基因型'], ['遺傳', '單基因遺傳-顯性遺傳(各種基因型之討論)'], ['遺傳', '單基因遺傳-中間型遺傳(不完全顯性)'], ['遺傳', '單基因遺傳-等顯性遺傳(ABO血型)'], ['遺傳', '單基因遺傳-性聯遺傳(紅綠色盲與父母的關係)'], ['遺傳', '多基因遺傳-人類的身高與膚色'], ['遺傳', ''], ['遺傳', '性'], ['遺傳', '遺傳的染色體學說'], ['遺傳', '連鎖群'], ['遺傳', 'DNA雙股螺旋構造與半保留複製'], ['遺傳', '基因、DNA與染色體的關係'], ['遺傳', '從基因到性狀 分子生物學的中心法則'], ['遺傳', '【實驗】基因檢測｜啾啾鞋的邊緣基因哪裡來？＜實驗科學吧＞'], ['遺傳', '細菌的染色體與質體'], ['遺傳', '重組DNA 產生胰島素的細菌'], ['遺傳', '基因轉殖技術的應用'], ['遺傳', '遺傳物質'], ['遺傳', '遺傳物質與'], ['遺傳', '【延伸】基因工程｜ROAR～重建侏儸紀公園的恐龍復活教戰手冊！？＜實驗科學吧＞']]
# [['演化與生物多樣性', '演化論前言-演化論的誤解'], ['演化與生物多樣性', '創造論(神創說)'], ['演化與生物多樣性', '拉馬克的演化理論(用進廢退說)'], ['演化與生物多樣性', '達爾文演化思想的孕育'], ['演化與生物多樣性', '達爾文的演化理論(天擇說)'], ['演化與生物多樣性', '用進廢退說vs.天擇說'], ['演化與生物多樣性', '【探究】天'], ['演化與生物多樣性', '現代的演化理論'], ['演化與生物多樣性', '抗藥性'], ['演化與生物多樣性', '生物種的概念'], ['演化與生物多樣性', ''], ['演化與生物多樣性', '生'], ['演化與生物多樣性', '生物分類系統的演進'], ['演化與生物多樣性', '生命樹與親緣關係'], ['演化與生物多樣性', '親緣關係的證據1-同源與痕跡構造'], ['演化與生物多樣性', '親緣關係的證據2-化石'], ['演化與生物多樣性', '親緣關係的證據3-地理分布情形'], ['演化與生物多樣性', '親緣關係的證據4-分子生物學證據'], ['演化與生物多樣性', '親緣關係的可重建性'], ['演化與生物多樣性', '病毒的定位'], ['演化與生物多樣性', ''], ['演化與生物多樣性', ''], ['演化與生物多樣性', '生物多樣性'], ['演化與生物多樣性', '遺傳多樣性'], ['演化與生物多樣性', '物種多樣性'], ['演化與生物多樣性', '生態系多樣性'], ['演化與生物多樣性', '維持生物多樣性的重要'], ['演化與生物多樣性', '生物多樣性面臨的挑戰'], ['演化與生物多樣性', ''], ['演化與生物多樣性', '生']]
# [['植物學', '植物的演化'], ['植物學', '草本植物的莖'], ['植物學', '木本莖與變態莖'], ['植物學', '植物的營養器官─葉'], ['植物學', '植物葉的變態'], ['植物學', ''], ['植物學', '植物的'], ['植物學', '營養構造表格'], ['植物學', '植物維管束木質部的運輸(水分無機鹽離子)'], ['植物學', '植物維管束韌皮部的物質運輸(有機養分)'], ['植物學', ''], ['植物學', '營養構'], ['植物學', '植物的無性生殖'], ['植物學', '植物花的構造與授粉作用'], ['植物學', '植物的世代交替與被子植物的有性生殖'], ['植物學', '果實與種子的發育'], ['植物學', '果實與種子的傳播'], ['植物學', ''], ['植物學', '生殖構'], ['植物學', '簡介植物對環境刺激的反應'], ['植物學', '植物的向性運動'], ['植物學', '植物的傾性運動'], ['植物學', '植物的光週期性'], ['植物學', '植物的春化作用'], ['植物學', '對'], ['植物學', '對環境刺']]
# [['動物生理學', '循環系統介紹'], ['動物生理學', '心臟的結構'], ['動物生理學', '心搏週期'], ['動物生理學', '血管的結構與功能'], ['動物生理學', '血壓'], ['動物生理學', '血液循環和淋巴循環'], ['動物生理學', ''], ['動物生理學', '動物的'], ['動物生理學', '消化作用與消化系統種類'], ['動物生理學', '人體的營養需求'], ['動物生理學', '人體的消化系統與功能'], ['動物生理學', '人體養分的吸收與運輸'], ['動物生理學', '肝臟的功能'], ['動物生理學', ''], ['動物生理學', '動物的'], ['動物生理學', '動物的呼吸器官'], ['動物生理學', '人類的呼吸系統'], ['動物生理學', '人體的呼吸運動'], ['動物生理學', '氣體的交換與運輸'], ['動物生理學', ''], ['動物生理學', '動物的'], ['動物生理學', '排泄系統與腎臟'], ['動物生理學', '腎元'], ['動物生理學', '尿液的形成'], ['動物生理學', ''], ['動物生理學', '動物的'], ['動物生理學', '防禦'], ['動物生理學', '皮膜防禦'], ['動物生理學', '吞噬作用、發炎反應'], ['動物生理學', '淋巴系統、初級淋巴器官、次級淋巴器官'], ['動物生理學', '專一性防禦介紹'], ['動物生理學', '體液免疫、細胞免疫'], ['動物生理學', '免疫記憶'], ['動物生理學', ''], ['動物生理學', '動物的'], ['動物生理學', '男性生殖系統'], ['動物生理學', '女性生殖系統'], ['動物生理學', '月經週期'], ['動物生理學', '人類配子的形成'], ['動物生理學', '受精、卵裂、胚胎發育'], ['動物生理學', ''], ['動物生理學', '動物的'], ['動物生理學', '協調作用簡介'], ['動物生理學', '神經系統的功能總覽'], ['動物生理學', '神經元與神經膠細胞'], ['動物生理學', '中樞神經系統─腦的簡要介紹'], ['動物生理學', '中樞神經系統─脊髓'], ['動物生理學', '周圍神經系統─腦神經與脊髓神經'], ['動物生理學', '神經系統的反射'], ['動物生理學', '隨意運動'], ['動物生理學', ''], ['動物生理學', '動物的'], ['動物生理學', '內分泌腺與激素的簡介'], ['動物生理學', '腦垂腺'], ['動物生理學', '甲狀腺與副甲狀腺'], ['動物生理學', '胰島素、升糖素與血糖調節'], ['動物生理學', '腎上腺與激素'], ['動物生理學', '性腺激素'], ['動物生理學', '動'], ['動物生理學', '動物的內'], ['動物生理學', '【專欄】珊瑚為何會同時間大量產卵？關鍵在日落到']]
# [['生物與環境', '生態系的生物與非生物因子'], ['生物與環境', '食物鏈與食物網']]
# [['動植物的組織', '動物組織的簡介'], ['動植物的組織', '結締組織'], ['動植物的組織', '結締組織   骨骼'], ['動植物的組織', '血液'], ['動植物的組織', '肌肉組織'], ['動植物的組織', '神經組織'], ['動植物的組織', '植物的組織與細胞'], ['動植物的組織', '植物的分生組織'], ['動植物的組織', '植物的表皮組織'], ['動植物的組織', '植物的維管束組織']]
# [['細胞化合物與細胞構造', '生物體內常見的糖類（構造與功能）'], ['細胞化合物與細胞構造', '生物體的有機化合物（蛋白質）'], ['細胞化合物與細胞構造', '脂質'], ['細胞化合物與細胞構造', '真核生物的細胞骨架'], ['細胞化合物與細胞構造', '中心體'], ['細胞化合物與細胞構造', '內膜系統'], ['細胞化合物與細胞構造', '半自主胞器（粒線體與葉綠體）']]
# [['光合作用', '可見光與光合色素'], ['光合作用', '光反應'], ['光合作用', '光合作用碳反應'], ['光合作用', 'C3、C4、CAM植物']]
# [['呼吸作用', '有氧呼吸'], ['呼吸作用', '發酵作用']]
# This is the last page ( •̀ ω •́ )✧
# This is the last page ( •̀ ω •́ )✧
# [['生命的特性', '生命現象概論', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/q_Kg-6KexXg'], ['生命的特性', '生命現象 代謝', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/0FPwEv7oEjY'], ['生命的特性', '從肥胖看生命現象之生長現象', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/0D7s7r78yBE'], ['生命的特性', '生命現象 感應與運動', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/1FinOPmSKt4'], ['生命的特性', '生命現象 繁殖', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/sv1x4UlI8Jw'], ['生命的特性', '', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/e/s5bsm-aa'], ['生命的特性', '細胞的發現與細胞學說', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/mIqMgRDhS94'], ['生命的特性', '細胞的大小(內有有趣的網站)', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/imHlBhs8rHY'], ['生命的特性', '科學方法(歌)', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/SI4nCB9E4lE'], ['生命的特性', '組成細胞的分子概論', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/CNB4A_0UBs4'], ['生命的特性', '組成細胞的分子 水', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/wp4YICOXnPs'], ['生命的特性', '組成細胞的分子 礦物質', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/VlbsJ95j8qk'], ['生命的特性', '組成細胞的分子 醣類', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/J09IynzUQ18'], ['生命的特性', '組成細胞的分子 脂質', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/RKkoWzVjonk'], ['生命的特性', '組成細胞的分子 蛋白質', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/eud5LzpsJsc'], ['生命的特性', '組成細胞的分子 核酸', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/OooOw48kT-k'], ['生命的特性', '', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/e/s5bsm-bb'], ['生命的特性', '從房間的概念看細胞', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/2pTN9RUNSJo'], ['生命的特性', '真核細胞與原核細胞的比較', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/tT_4tBYsCIg'], ['生命的特性', '真核細胞的基本構造 細胞膜與細胞壁', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/GysMfICI6e4'], ['生命的特性', '真核細胞的基本構造 細胞核', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/rxgd63cBcHc'], ['生命的特性', '真核細胞的基本構造 細胞質與胞器的簡介', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/wtQNu274FuA'], ['生命的特性', '胞器介紹 非膜狀構造：核糖體與中心粒', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/3c0l0UfE68I'], ['生命的特性', '胞器介紹 單層膜狀胞器：內質網、高基氏體、液泡', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/-IQV6frnLwo'], ['生命的特性', '胞器介紹 雙層膜狀胞器：粒腺體與葉綠體', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/kVVqOf1vOmg'], ['生命的特性', '', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/e/s5bsm-bc'], ['生命的特性', '', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/e/s5bsm-ba'], ['生命的特性', '半透膜的定義與細胞膜脂雙層的通透性', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/RMqIymwUZXw'], ['生命的特性', '被動運輸 簡單擴散', 'https://www.junyiacademy.org//junyi-science/science-high/junyi-biology/junyi-properties-of-life/v/Vtn867HUBMI'], ...

# %%
data_column_name = ["單元", "課程名稱", "網址"]
df = pd.DataFrame(data, columns=data_column_name)
df.to_csv("均一高中生物.csv", index=False, encoding="utf-8")
